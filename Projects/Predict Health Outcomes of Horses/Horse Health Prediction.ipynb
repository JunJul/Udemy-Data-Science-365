# %%
import numpy as np
import pandas as pd
import numbers
from collections import Counter

# display all the columns when output the dataframe
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

np.set_printoptions(threshold=np.inf)

# %% [markdown]
# ## Load the data

# %%
# read the file
data = pd.read_csv('train.csv')

# %%
data.head()
# Out:
#    id surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0   0     yes  adult           530001         38.1  132.0              24.0
# 1   1     yes  adult           533836         37.5   88.0              12.0
# 2   2     yes  adult           529812         38.3  120.0              28.0
# 3   3     yes  adult          5262541         37.1   72.0              30.0
# 4   4      no  adult          5299629         38.0   52.0              48.0
#
#   temp_of_extremities peripheral_pulse mucous_membrane capillary_refill_time  \
# 0                cool          reduced   dark_cyanotic            more_3_sec
# 1                cool           normal   pale_cyanotic            more_3_sec
# 2                cool          reduced       pale_pink            less_3_sec
# 3                cold          reduced       pale_pink            more_3_sec
# 4              normal           normal     normal_pink            less_3_sec
#
#            pain peristalsis abdominal_distention nasogastric_tube  \
# 0     depressed      absent               slight           slight
# 1     mild_pain      absent             moderate             none
# 2  extreme_pain  hypomotile             moderate           slight
# 3     mild_pain  hypomotile             moderate           slight
# 4         alert  hypomotile                 none           slight
#
#   nasogastric_reflux  nasogastric_reflux_ph rectal_exam_feces        abdomen  \
# 0       less_1_liter                    6.5         decreased  distend_small
# 1       more_1_liter                    2.0            absent  distend_small
# 2               none                    3.5               NaN  distend_large
# 3       more_1_liter                    2.0         decreased  distend_small
# 4       less_1_liter                    7.0            normal         normal
#
#    packed_cell_volume  total_protein abdomo_appearance  abdomo_protein  \
# 0                57.0            8.5     serosanguious             3.4
# 1                33.0           64.0     serosanguious             2.0
# 2                37.0            6.4     serosanguious             3.4
# 3                53.0            7.0            cloudy             3.9
# 4                47.0            7.3            cloudy             2.6
#
#   surgical_lesion  lesion_1  lesion_2  lesion_3 cp_data     outcome
# 0             yes      2209         0         0      no        died
# 1             yes      2208         0         0      no  euthanized
# 2             yes      5124         0         0      no       lived
# 3             yes      2208         0         0     yes       lived
# 4              no         0         0         0     yes       lived

# %%
data.describe(include='all')
# Out:
#                id surgery    age  hospital_number  rectal_temp        pulse  \
# count   1235.0000    1235   1235     1.235000e+03  1235.000000  1235.000000
# unique        NaN       2      2              NaN          NaN          NaN
# top           NaN     yes  adult              NaN          NaN          NaN
# freq          NaN     887   1160              NaN          NaN          NaN
# mean     617.0000     NaN    NaN     9.545004e+05    38.202186    79.574089
# std      356.6581     NaN    NaN     1.356403e+06     0.788668    29.108638
# min        0.0000     NaN    NaN     5.213990e+05    35.400000    30.000000
# 25%      308.5000     NaN    NaN     5.288000e+05    37.800000    53.000000
# 50%      617.0000     NaN    NaN     5.297770e+05    38.200000    76.000000
# 75%      925.5000     NaN    NaN     5.341450e+05    38.600000   100.000000
# max     1234.0000     NaN    NaN     5.305129e+06    40.800000   184.000000
#
#         respiratory_rate temp_of_extremities peripheral_pulse mucous_membrane  \
# count        1235.000000                1196             1175            1214
# unique               NaN                   4                4               6
# top                  NaN                cool          reduced       pale_pink
# freq                 NaN                 700              724             284
# mean           30.054251                 NaN              NaN             NaN
# std            16.452066                 NaN              NaN             NaN
# min             8.000000                 NaN              NaN             NaN
# 25%            18.000000                 NaN              NaN             NaN
# 50%            28.000000                 NaN              NaN             NaN
# 75%            36.000000                 NaN              NaN             NaN
# max            96.000000                 NaN              NaN             NaN
#
#        capillary_refill_time       pain peristalsis abdominal_distention  \
# count                   1229       1191        1215                 1212
# unique                     3          6           5                    4
# top               less_3_sec  depressed  hypomotile             moderate
# freq                     834        429         664                  543
# mean                     NaN        NaN         NaN                  NaN
# std                      NaN        NaN         NaN                  NaN
# min                      NaN        NaN         NaN                  NaN
# 25%                      NaN        NaN         NaN                  NaN
# 50%                      NaN        NaN         NaN                  NaN
# 75%                      NaN        NaN         NaN                  NaN
# max                      NaN        NaN         NaN                  NaN
#
#        nasogastric_tube nasogastric_reflux  nasogastric_reflux_ph  \
# count              1155               1214            1235.000000
# unique                3                  4                    NaN
# top              slight       more_1_liter                    NaN
# freq                758                604                    NaN
# mean                NaN                NaN               4.382591
# std                 NaN                NaN               1.937357
# min                 NaN                NaN               1.000000
# 25%                 NaN                NaN               2.000000
# 50%                 NaN                NaN               4.500000
# 75%                 NaN                NaN               6.000000
# max                 NaN                NaN               7.500000
#
#        rectal_exam_feces        abdomen  packed_cell_volume  total_protein  \
# count               1045           1022         1235.000000    1235.000000
# unique                 5              5                 NaN            NaN
# top               absent  distend_small                 NaN            NaN
# freq                 493            482                 NaN            NaN
# mean                 NaN            NaN           49.602429      21.388016
# std                  NaN            NaN           10.535800      26.676453
# min                  NaN            NaN           23.000000       3.500000
# 25%                  NaN            NaN           43.000000       6.600000
# 50%                  NaN            NaN           48.000000       7.500000
# 75%                  NaN            NaN           57.000000       9.100000
# max                  NaN            NaN           75.000000      89.000000
#
#        abdomo_appearance  abdomo_protein surgical_lesion      lesion_1  \
# count               1187     1235.000000            1235   1235.000000
# unique                 3             NaN               2           NaN
# top        serosanguious             NaN             yes           NaN
# freq                 570             NaN             929           NaN
# mean                 NaN        3.290931             NaN   3832.496356
# std                  NaN        1.589195             NaN   5436.733774
# min                  NaN        0.100000             NaN      0.000000
# 25%                  NaN        2.000000             NaN   2205.000000
# 50%                  NaN        3.000000             NaN   2209.000000
# 75%                  NaN        4.300000             NaN   3205.000000
# max                  NaN       10.100000             NaN  41110.000000
#
#            lesion_2     lesion_3 cp_data outcome
# count   1235.000000  1235.000000    1235    1235
# unique          NaN          NaN       2       3
# top             NaN          NaN     yes   lived
# freq            NaN          NaN     668     574
# mean      14.612146     3.577328     NaN     NaN
# std      193.705735    88.858953     NaN     NaN
# min        0.000000     0.000000     NaN     NaN
# 25%        0.000000     0.000000     NaN     NaN
# 50%        0.000000     0.000000     NaN     NaN
# 75%        0.000000     0.000000     NaN     NaN
# max     3112.000000  2209.000000     NaN     NaN

# %% [markdown]
# ## Select useful information for the model

# %%
# select all the rows and select from only the col1 to the last col
# id is usefuless in the model, so I do not need to include it
interested_data = data.iloc[:, 1:]

# concat the origin dataset into the train dataset as well
interested_data = pd.concat([interested_data, pd.read_csv('origin.csv')], axis=0)
interested_data = interested_data.reset_index(drop=True)

interested_data = interested_data.drop(['hospital_number'], axis=1)

# %% [markdown]
# ## Dealing with the missing values

# %%
table = interested_data.describe(include='all')
table
# Out:
#        surgery    age  rectal_temp        pulse  respiratory_rate  \
# count     1534   1534  1474.000000  1510.000000       1476.000000
# unique       2      2          NaN          NaN               NaN
# top        yes  adult          NaN          NaN               NaN
# freq      1067   1435          NaN          NaN               NaN
# mean       NaN    NaN    38.196744    78.194702         30.120596
# std        NaN    NaN     0.779883    29.162518         16.650801
# min        NaN    NaN    35.400000    30.000000          8.000000
# 25%        NaN    NaN    37.800000    52.000000         18.000000
# 50%        NaN    NaN    38.200000    72.000000         28.000000
# 75%        NaN    NaN    38.600000    96.000000         36.000000
# max        NaN    NaN    40.800000   184.000000         96.000000
#
#        temp_of_extremities peripheral_pulse mucous_membrane  \
# count                 1439             1405            1466
# unique                   4                4               6
# top                   cool          reduced       pale_pink
# freq                   808              827             341
# mean                   NaN              NaN             NaN
# std                    NaN              NaN             NaN
# min                    NaN              NaN             NaN
# 25%                    NaN              NaN             NaN
# 50%                    NaN              NaN             NaN
# 75%                    NaN              NaN             NaN
# max                    NaN              NaN             NaN
#
#        capillary_refill_time       pain peristalsis abdominal_distention  \
# count                   1496       1435        1470                 1455
# unique                     3          6           5                    4
# top               less_3_sec  depressed  hypomotile             moderate
# freq                    1021        488         791                  608
# mean                     NaN        NaN         NaN                  NaN
# std                      NaN        NaN         NaN                  NaN
# min                      NaN        NaN         NaN                  NaN
# 25%                      NaN        NaN         NaN                  NaN
# 50%                      NaN        NaN         NaN                  NaN
# 75%                      NaN        NaN         NaN                  NaN
# max                      NaN        NaN         NaN                  NaN
#
#        nasogastric_tube nasogastric_reflux  nasogastric_reflux_ph  \
# count              1350               1407            1288.000000
# unique                3                  4                    NaN
# top              slight       more_1_liter                    NaN
# freq                859                643                    NaN
# mean                NaN                NaN               4.395963
# std                 NaN                NaN               1.939516
# min                 NaN                NaN               1.000000
# 25%                 NaN                NaN               2.000000
# 50%                 NaN                NaN               4.500000
# 75%                 NaN                NaN               6.200000
# max                 NaN                NaN               7.500000
#
#        rectal_exam_feces        abdomen  packed_cell_volume  total_protein  \
# count               1242           1203         1505.000000    1501.000000
# unique                 5              5                 NaN            NaN
# top               absent  distend_small                 NaN            NaN
# freq                 572            525                 NaN            NaN
# mean                 NaN            NaN           49.011296      21.899534
# std                  NaN            NaN           10.590426      26.813063
# min                  NaN            NaN           23.000000       3.300000
# 25%                  NaN            NaN           42.000000       6.600000
# 50%                  NaN            NaN           48.000000       7.500000
# 75%                  NaN            NaN           55.000000      13.000000
# max                  NaN            NaN           75.000000      89.000000
#
#        abdomo_appearance  abdomo_protein surgical_lesion      lesion_1  \
# count               1321     1336.000000            1534   1534.000000
# unique                 3             NaN               2           NaN
# top        serosanguious             NaN             yes           NaN
# freq                 616             NaN            1119           NaN
# mean                 NaN        3.271931             NaN   3798.817471
# std                  NaN        1.621415             NaN   5429.907956
# min                  NaN        0.100000             NaN      0.000000
# 25%                  NaN        2.000000             NaN   2124.000000
# 50%                  NaN        3.000000             NaN   2209.000000
# 75%                  NaN        4.300000             NaN   3205.000000
# max                  NaN       10.100000             NaN  41110.000000
#
#            lesion_2     lesion_3 cp_data outcome
# count   1534.000000  1534.000000    1534    1534
# unique          NaN          NaN       2       3
# top             NaN          NaN      no   lived
# freq            NaN          NaN     767     752
# mean      29.409387     4.320078     NaN     NaN
# std      336.748319    97.624805     NaN     NaN
# min        0.000000     0.000000     NaN     NaN
# 25%        0.000000     0.000000     NaN     NaN
# 50%        0.000000     0.000000     NaN     NaN
# 75%        0.000000     0.000000     NaN     NaN
# max     7111.000000  2209.000000     NaN     NaN

# %%
# the built in function isnull().sum() return a series of numpy and like a dictionary
nan_data = interested_data.isnull().sum()

# just a dictionary
nan_data
# Out:
# surgery                    0
# age                        0
# rectal_temp               60
# pulse                     24
# respiratory_rate          58
# temp_of_extremities       95
# peripheral_pulse         129
# mucous_membrane           68
# capillary_refill_time     38
# pain                      99
# peristalsis               64
# abdominal_distention      79
# nasogastric_tube         184
# nasogastric_reflux       127
# nasogastric_reflux_ph    246
# rectal_exam_feces        292
# abdomen                  331
# packed_cell_volume        29
# total_protein             33
# abdomo_appearance        213
# abdomo_protein           198
# surgical_lesion            0
# lesion_1                   0
# lesion_2                   0
# lesion_3                   0
# cp_data                    0
# outcome                    0
# dtype: int64

# %%
def getNan_cols(nan_data): 
    # create a variable to store the columns which has nan values
    numerical_nan_data_cols=[]
    categorical_nan_data_cols=[]
    
    # iterate the keys in nan_data
    for i in nan_data.keys():
        if nan_data[i] > 0:
            if isinstance(interested_data[i].values[0], numbers.Number):
                numerical_nan_data_cols.append(i)
            else:
                categorical_nan_data_cols.append(i)
                
    if (len(numerical_nan_data_cols) > 0) & (len(categorical_nan_data_cols) > 0):
        return numerical_nan_data_cols, categorical_nan_data_cols
    elif len(numerical_nan_data_cols) > 0:
        return numerical_nan_data_cols
    else:
        return categorical_nan_data_cols

# %%
#numerical_nan_data_cols, 
numerical_nan_data_cols, categorical_nan_data_cols = getNan_cols(nan_data)

# %%
# the fillNan function is used to fill out the nan values with mean value in the dataframe
def categorical_fillNan(nan_data_cols, dataframe, table):
    
    # iterate the cols with nan values
    for i in nan_data_cols:
        
        # get the top value
        top = table[i].top
        
        # fill the nan values with the mean
        dataframe[i] = dataframe[i].fillna(top)
        
    return dataframe

# %%
def numberical_fillNan(nan_data_cols, dataframe):
     # iterate the cols with nan values
    for i in nan_data_cols:
        
        # get the top value
        mean = int(table[i].mean())
        
        # fill the nan values with the mean
        dataframe[i] = dataframe[i].fillna(mean)
        
    return dataframe

# %%
# call the categorical_fillNan function
noNan_data = categorical_fillNan(categorical_nan_data_cols, interested_data, table)

# call the numerical_fillNan
noNan_data = numberical_fillNan(numerical_nan_data_cols, noNan_data)

# %%
# Preprocessing finished
data_preprocessed = noNan_data.copy()

# %% [markdown]
# ## Get the input and the target

# %%
input_data = data_preprocessed.iloc[:, :len(data_preprocessed.columns)-1]
target_data = data_preprocessed['outcome']

# %% [markdown]
# ## Get dummies

# %%
dummies_input_data = pd.get_dummies(input_data, dtype=int, drop_first=True)
dummies_target_data = target_data.map({'died': 0, 'euthanized': 1, 'lived': 2})

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# #### Determine the significance of each individual variable to the model
# #### The lower the p value that a variable has, the greater impact it has to the model

# %%
# import f_regression to calculate the p_values
from sklearn.feature_selection import f_regression

# %%
# calculate and return two arrays
p_values = f_regression(dummies_input_data, dummies_target_data)
# the array in index 1 is the p values and round it to the third digit
p_values = p_values[1].round(3)

# %%
# create a dataframe to display the p_values
p_value_table = pd.DataFrame({'Features': dummies_input_data.columns, 'P_values': p_values})
p_value_table
# Out:
#                             Features  P_values
# 0                        rectal_temp     0.214
# 1                              pulse     0.000
# 2                   respiratory_rate     0.014
# 3              nasogastric_reflux_ph     0.000
# 4                 packed_cell_volume     0.000
# 5                      total_protein     0.000
# 6                     abdomo_protein     0.001
# 7                           lesion_1     0.480
# 8                           lesion_2     0.019
# 9                           lesion_3     0.332
# 10                       surgery_yes     0.000
# 11                         age_young     0.000
# 12          temp_of_extremities_cool     0.000
# 13        temp_of_extremities_normal     0.000
# 14          temp_of_extremities_warm     0.000
# 15        peripheral_pulse_increased     0.192
# 16           peripheral_pulse_normal     0.000
# 17          peripheral_pulse_reduced     0.000
# 18        mucous_membrane_bright_red     0.000
# 19     mucous_membrane_dark_cyanotic     0.000
# 20       mucous_membrane_normal_pink     0.000
# 21     mucous_membrane_pale_cyanotic     0.000
# 22         mucous_membrane_pale_pink     0.111
# 23  capillary_refill_time_less_3_sec     0.000
# 24  capillary_refill_time_more_3_sec     0.000
# 25                    pain_depressed     0.000
# 26                 pain_extreme_pain     0.000
# 27                    pain_mild_pain     0.000
# 28                  pain_severe_pain     0.000
# 29                       pain_slight     0.845
# 30         peristalsis_distend_small     0.845
# 31           peristalsis_hypermotile     0.000
# 32            peristalsis_hypomotile     0.030
# 33                peristalsis_normal     0.000
# 34         abdominal_distention_none     0.000
# 35       abdominal_distention_severe     0.000
# 36       abdominal_distention_slight     0.000
# 37      nasogastric_tube_significant     0.137
# 38           nasogastric_tube_slight     0.056
# 39   nasogastric_reflux_more_1_liter     0.203
# 40           nasogastric_reflux_none     0.072
# 41         nasogastric_reflux_slight     0.348
# 42       rectal_exam_feces_decreased     0.003
# 43       rectal_exam_feces_increased     0.850
# 44          rectal_exam_feces_normal     0.000
# 45   rectal_exam_feces_serosanguious     0.348
# 46             abdomen_distend_small     0.001
# 47                      abdomen_firm     0.000
# 48                    abdomen_normal     0.028
# 49                     abdomen_other     0.000
# 50          abdomo_appearance_cloudy     0.001
# 51   abdomo_appearance_serosanguious     0.000
# 52               surgical_lesion_yes     0.000
# 53                       cp_data_yes     0.885

# %% [markdown]
# ## Balance the outcome

# %% [markdown]
# #### The outcomes are died, euthanized, and lived, and the number of their occurence in the dataset should be euqal.

# %%
# The function is to calculate the frequencies of each variable in the list
def frequencies_outcome(data):
    # get the frequency
    counter = Counter(data)
    print(counter)
    # find the smallest value in the dictionary and return its key
    smallest = min(counter, key=counter.get)
    return smallest, counter[smallest]

# %%
def balance_outcome(data):
    # call the frequencies_outcome to get the smallest frequncies of an output with its key
    smallest_frequency_key, smallest_frequency = frequencies_outcome(data)
    
    # create dict_total to represent the total number of freuqueny that match the smallest frequency
    dict_total = {'0': smallest_frequency,
                 '2': smallest_frequency}
    
    # create a dictionary to count the number of three different outputs
    dict_count = {}
    
    # store the indices of row needs to be removed from the list
    removed_indices = []
    
    # create a for loop to iterate the data by indcies
    for i in range(len(data)):
        # get a value from the output
        outcome = str(data[i])
        
        # if outcome is smallest_frequency_key, execute continue
        # else-if: the outcome in the keys of dict_count, enter inside and check the inner if-statement, 
        # else: assgin value 1 to the value  
                # if the counts in dict_count is smaller than the total counts, add 1 
                    # otherwise, it exceeds the total count of a particular output
        if outcome == str(smallest_frequency_key):
            continue
        elif outcome in dict_count.keys():
            if dict_count[outcome] < dict_total[outcome]:
                dict_count[outcome] += 1
            else:
                removed_indices.append(i)
        else:
            dict_count[outcome] = 1
    
    return removed_indices

# %%
# call the balance_outcome function to get the removed incdices
removed_indices = balance_outcome(dummies_target_data)
# Out:
# Counter({2: 752, 0: 487, 1: 295})

# %%
# drop excessive data and reset the index 
balanced_input_data = dummies_input_data.drop(removed_indices, axis=0).reset_index(drop=True)
balanced_target_data = dummies_target_data.drop(removed_indices, axis=0).reset_index(drop=True)

#balanced_input_data = dummies_input_data.copy()
#balanced_target_data = dummies_target_data.copy()

# %%
counter  = Counter(balanced_target_data)
print(counter)
# Out:
# Counter({0: 295, 1: 295, 2: 295})

# %% [markdown]
# ## Shuffle

# %%
import random

# %%
shuffled_indices = np.arange(balanced_input_data.shape[0])
random.shuffle(shuffled_indices)

# %%
shuffled_input_data = balanced_input_data.iloc[shuffled_indices].reset_index(drop=True)
shuffled_target_data = balanced_target_data[shuffled_indices].reset_index(drop=True)

#shuffled_input_data = balanced_input_data
#shuffled_target_data = balanced_target_data

# %%
print(interested_data['outcome'].unique())
# Out:
# ['died' 'euthanized' 'lived']

# %% [markdown]
# #### 0: died
# #### 1: euthanized
# #### 2: lived

# %% [markdown]
# ## Scale the input data

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler.fit(shuffled_input_data)
scaled_input_data = scaler.transform(shuffled_input_data)

# %% [markdown]
# ## Split

# %%
# split the data into three parts
train_counts = int(0.8*scaled_input_data.shape[0])
validation_counts = int(0.1*scaled_input_data.shape[0])

train_input = scaled_input_data[:train_counts]
train_target = shuffled_target_data[:train_counts]

validation_input = scaled_input_data[train_counts: train_counts+validation_counts]
validation_target = shuffled_target_data[train_counts: train_counts+validation_counts]

test_input = scaled_input_data[train_counts+validation_counts :]
test_target = shuffled_target_data[train_counts+validation_counts :]

#test_input = scaled_input_data[train_counts:]
#test_target = shuffled_target_data[train_counts:]

# %% [markdown]
# ## Deep Learning Modeling

# %%
import tensorflow as tf
input_size = train_input.shape[1]
output_size = 3
hidden_layer = 100

# create the model with two hidden layers and eahc hidden layers has 50 units
    # use relu for hidden layers and softmax for the output layer
model = tf.keras.Sequential([
    #tf.keras.layers.Input(shape=(input_size,)),
    tf.keras.layers.Dense(hidden_layer, activation='relu'),
    tf.keras.layers.Dense(hidden_layer, activation='relu'),
    tf.keras.layers.Dense(output_size, activation='softmax')
])

# %%
customized_optimizer = tf.keras.optimizers.Adam()

model.compile(optimizer=customized_optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(patience=1)
max_epochs = 100
batch_size = 100

model.fit(train_input,
         train_target,
         epochs=max_epochs,
         batch_size=batch_size,
         validation_data=(validation_input, validation_target),
         verbose=2)
# Out:
# Epoch 1/100
# 8/8 - 1s - loss: 1.0839 - accuracy: 0.4138 - val_loss: 0.9742 - val_accuracy: 0.5341 - 964ms/epoch - 121ms/step
# Epoch 2/100
# 8/8 - 0s - loss: 0.9052 - accuracy: 0.5989 - val_loss: 0.9052 - val_accuracy: 0.6023 - 55ms/epoch - 7ms/step
# Epoch 3/100
# 8/8 - 0s - loss: 0.8250 - accuracy: 0.6299 - val_loss: 0.8908 - val_accuracy: 0.6364 - 51ms/epoch - 6ms/step
# Epoch 4/100
# 8/8 - 0s - loss: 0.7776 - accuracy: 0.6483 - val_loss: 0.8603 - val_accuracy: 0.6364 - 50ms/epoch - 6ms/step
# Epoch 5/100
# 8/8 - 0s - loss: 0.7363 - accuracy: 0.6737 - val_loss: 0.8202 - val_accuracy: 0.6591 - 46ms/epoch - 6ms/step
# Epoch 6/100
# 8/8 - 0s - loss: 0.7045 - accuracy: 0.7048 - val_loss: 0.7905 - val_accuracy: 0.6818 - 46ms/epoch - 6ms/step
# Epoch 7/100
# 8/8 - 0s - loss: 0.6753 - accuracy: 0.7119 - val_loss: 0.7736 - val_accuracy: 0.6818 - 50ms/epoch - 6ms/step
# Epoch 8/100
# 8/8 - 0s - loss: 0.6496 - accuracy: 0.7288 - val_loss: 0.7661 - val_accuracy: 0.6818 - 45ms/epoch - 6ms/step
# Epoch 9/100
# 8/8 - 0s - loss: 0.6251 - accuracy: 0.7486 - val_loss: 0.7589 - val_accuracy: 0.6818 - 46ms/epoch - 6ms/step
# Epoch 10/100
# 8/8 - 0s - loss: 0.6019 - accuracy: 0.7528 - val_loss: 0.7537 - val_accuracy: 0.6932 - 46ms/epoch - 6ms/step
# Epoch 11/100
# 8/8 - 0s - loss: 0.5850 - accuracy: 0.7655 - val_loss: 0.7379 - val_accuracy: 0.6932 - 45ms/epoch - 6ms/step
# Epoch 12/100
# 8/8 - 0s - loss: 0.5646 - accuracy: 0.7853 - val_loss: 0.7567 - val_accuracy: 0.7045 - 42ms/epoch - 5ms/step
# Epoch 13/100
# 8/8 - 0s - loss: 0.5528 - accuracy: 0.7811 - val_loss: 0.7527 - val_accuracy: 0.7045 - 40ms/epoch - 5ms/step
# Epoch 14/100
# 8/8 - 0s - loss: 0.5347 - accuracy: 0.7797 - val_loss: 0.7352 - val_accuracy: 0.7045 - 35ms/epoch - 4ms/step
# Epoch 15/100
# 8/8 - 0s - loss: 0.5179 - accuracy: 0.7980 - val_loss: 0.7241 - val_accuracy: 0.6932 - 35ms/epoch - 4ms/step
# Epoch 16/100
# 8/8 - 0s - loss: 0.5032 - accuracy: 0.8065 - val_loss: 0.7302 - val_accuracy: 0.7045 - 95ms/epoch - 12ms/step
# Epoch 17/100
# 8/8 - 0s - loss: 0.4887 - accuracy: 0.8121 - val_loss: 0.7347 - val_accuracy: 0.7045 - 95ms/epoch - 12ms/step
# Epoch 18/100
# 8/8 - 0s - loss: 0.4739 - accuracy: 0.8249 - val_loss: 0.7532 - val_accuracy: 0.6932 - 100ms/epoch - 13ms/step
# Epoch 19/100
# 8/8 - 0s - loss: 0.4603 - accuracy: 0.8234 - val_loss: 0.7600 - val_accuracy: 0.7045 - 116ms/epoch - 15ms/step
# Epoch 20/100
# 8/8 - 0s - loss: 0.4467 - accuracy: 0.8263 - val_loss: 0.7738 - val_accuracy: 0.7045 - 90ms/epoch - 11ms/step
# Epoch 21/100
# 8/8 - 0s - loss: 0.4333 - accuracy: 0.8319 - val_loss: 0.7895 - val_accuracy: 0.6932 - 95ms/epoch - 12ms/step
# Epoch 22/100
# 8/8 - 0s - loss: 0.4200 - accuracy: 0.8418 - val_loss: 0.7918 - val_accuracy: 0.7045 - 92ms/epoch - 11ms/step
# Epoch 23/100
# 8/8 - 0s - loss: 0.4088 - accuracy: 0.8517 - val_loss: 0.7952 - val_accuracy: 0.6932 - 90ms/epoch - 11ms/step
# Epoch 24/100
# 8/8 - 0s - loss: 0.3941 - accuracy: 0.8602 - val_loss: 0.8135 - val_accuracy: 0.7045 - 107ms/epoch - 13ms/step
# Epoch 25/100
# 8/8 - 0s - loss: 0.3800 - accuracy: 0.8686 - val_loss: 0.7973 - val_accuracy: 0.6932 - 95ms/epoch - 12ms/step
# Epoch 26/100
# 8/8 - 0s - loss: 0.3695 - accuracy: 0.8616 - val_loss: 0.8034 - val_accuracy: 0.7045 - 100ms/epoch - 12ms/step
# Epoch 27/100
# 8/8 - 0s - loss: 0.3611 - accuracy: 0.8701 - val_loss: 0.8067 - val_accuracy: 0.6932 - 98ms/epoch - 12ms/step
# Epoch 28/100
# 8/8 - 0s - loss: 0.3449 - accuracy: 0.8757 - val_loss: 0.8193 - val_accuracy: 0.6932 - 96ms/epoch - 12ms/step
# Epoch 29/100
# 8/8 - 0s - loss: 0.3325 - accuracy: 0.8856 - val_loss: 0.8386 - val_accuracy: 0.6818 - 104ms/epoch - 13ms/step
# Epoch 30/100
# 8/8 - 0s - loss: 0.3253 - accuracy: 0.8912 - val_loss: 0.8512 - val_accuracy: 0.6932 - 100ms/epoch - 12ms/step
# Epoch 31/100
# 8/8 - 0s - loss: 0.3137 - accuracy: 0.9025 - val_loss: 0.8462 - val_accuracy: 0.6932 - 95ms/epoch - 12ms/step
# Epoch 32/100
# 8/8 - 0s - loss: 0.3064 - accuracy: 0.8997 - val_loss: 0.8778 - val_accuracy: 0.6932 - 95ms/epoch - 12ms/step
# Epoch 33/100
# 8/8 - 0s - loss: 0.2916 - accuracy: 0.9068 - val_loss: 0.8847 - val_accuracy: 0.6705 - 94ms/epoch - 12ms/step
# Epoch 34/100
# 8/8 - 0s - loss: 0.2802 - accuracy: 0.9251 - val_loss: 0.8793 - val_accuracy: 0.7045 - 105ms/epoch - 13ms/step
# Epoch 35/100
# 8/8 - 0s - loss: 0.2696 - accuracy: 0.9308 - val_loss: 0.8816 - val_accuracy: 0.6591 - 98ms/epoch - 12ms/step
# Epoch 36/100
# 8/8 - 0s - loss: 0.2636 - accuracy: 0.9379 - val_loss: 0.8948 - val_accuracy: 0.6705 - 97ms/epoch - 12ms/step
# Epoch 37/100
# 8/8 - 0s - loss: 0.2531 - accuracy: 0.9294 - val_loss: 0.9193 - val_accuracy: 0.7045 - 97ms/epoch - 12ms/step
# Epoch 38/100
# 8/8 - 0s - loss: 0.2476 - accuracy: 0.9322 - val_loss: 0.9308 - val_accuracy: 0.6705 - 90ms/epoch - 11ms/step
# Epoch 39/100
# 8/8 - 0s - loss: 0.2392 - accuracy: 0.9435 - val_loss: 0.9389 - val_accuracy: 0.6705 - 115ms/epoch - 14ms/step
# Epoch 40/100
# 8/8 - 0s - loss: 0.2277 - accuracy: 0.9350 - val_loss: 0.9554 - val_accuracy: 0.6932 - 100ms/epoch - 13ms/step
# Epoch 41/100
# 8/8 - 0s - loss: 0.2181 - accuracy: 0.9477 - val_loss: 0.9618 - val_accuracy: 0.6818 - 100ms/epoch - 12ms/step
# Epoch 42/100
# 8/8 - 0s - loss: 0.2090 - accuracy: 0.9506 - val_loss: 0.9811 - val_accuracy: 0.6818 - 99ms/epoch - 12ms/step
# Epoch 43/100
# 8/8 - 0s - loss: 0.1995 - accuracy: 0.9492 - val_loss: 0.9876 - val_accuracy: 0.7045 - 120ms/epoch - 15ms/step
# Epoch 44/100
# 8/8 - 0s - loss: 0.1941 - accuracy: 0.9605 - val_loss: 0.9891 - val_accuracy: 0.6932 - 103ms/epoch - 13ms/step
# Epoch 45/100
# 8/8 - 0s - loss: 0.1830 - accuracy: 0.9633 - val_loss: 1.0102 - val_accuracy: 0.6818 - 93ms/epoch - 12ms/step
# Epoch 46/100
# 8/8 - 0s - loss: 0.1742 - accuracy: 0.9689 - val_loss: 1.0197 - val_accuracy: 0.6705 - 95ms/epoch - 12ms/step
# Epoch 47/100
# 8/8 - 0s - loss: 0.1687 - accuracy: 0.9689 - val_loss: 1.0369 - val_accuracy: 0.6591 - 99ms/epoch - 12ms/step
# Epoch 48/100
# 8/8 - 0s - loss: 0.1664 - accuracy: 0.9675 - val_loss: 1.0468 - val_accuracy: 0.6932 - 94ms/epoch - 12ms/step
# Epoch 49/100
# 8/8 - 0s - loss: 0.1550 - accuracy: 0.9760 - val_loss: 1.0756 - val_accuracy: 0.6591 - 100ms/epoch - 12ms/step
# Epoch 50/100
# 8/8 - 0s - loss: 0.1519 - accuracy: 0.9647 - val_loss: 1.0880 - val_accuracy: 0.6705 - 95ms/epoch - 12ms/step
# Epoch 51/100
# 8/8 - 0s - loss: 0.1472 - accuracy: 0.9718 - val_loss: 1.0753 - val_accuracy: 0.6818 - 100ms/epoch - 13ms/step
# Epoch 52/100
# 8/8 - 0s - loss: 0.1411 - accuracy: 0.9802 - val_loss: 1.1054 - val_accuracy: 0.6932 - 101ms/epoch - 13ms/step
# Epoch 53/100
# 8/8 - 0s - loss: 0.1358 - accuracy: 0.9845 - val_loss: 1.1261 - val_accuracy: 0.6250 - 90ms/epoch - 11ms/step
# Epoch 54/100
# 8/8 - 0s - loss: 0.1281 - accuracy: 0.9845 - val_loss: 1.1508 - val_accuracy: 0.6818 - 100ms/epoch - 12ms/step
# Epoch 55/100
# 8/8 - 0s - loss: 0.1227 - accuracy: 0.9845 - val_loss: 1.1709 - val_accuracy: 0.6818 - 95ms/epoch - 12ms/step
# Epoch 56/100
# 8/8 - 0s - loss: 0.1170 - accuracy: 0.9873 - val_loss: 1.1637 - val_accuracy: 0.6705 - 99ms/epoch - 12ms/step
# Epoch 57/100
# 8/8 - 0s - loss: 0.1103 - accuracy: 0.9845 - val_loss: 1.1652 - val_accuracy: 0.6818 - 100ms/epoch - 13ms/step
# Epoch 58/100
# 8/8 - 0s - loss: 0.1070 - accuracy: 0.9901 - val_loss: 1.1506 - val_accuracy: 0.6932 - 95ms/epoch - 12ms/step
# Epoch 59/100
# 8/8 - 0s - loss: 0.1061 - accuracy: 0.9915 - val_loss: 1.1895 - val_accuracy: 0.6932 - 100ms/epoch - 12ms/step
# Epoch 60/100
# 8/8 - 0s - loss: 0.0979 - accuracy: 0.9915 - val_loss: 1.2700 - val_accuracy: 0.6591 - 100ms/epoch - 13ms/step
# Epoch 61/100
# 8/8 - 0s - loss: 0.0981 - accuracy: 0.9901 - val_loss: 1.3030 - val_accuracy: 0.6705 - 95ms/epoch - 12ms/step
# Epoch 62/100
# 8/8 - 0s - loss: 0.0908 - accuracy: 0.9887 - val_loss: 1.2890 - val_accuracy: 0.6818 - 95ms/epoch - 12ms/step
# Epoch 63/100
# 8/8 - 0s - loss: 0.0959 - accuracy: 0.9845 - val_loss: 1.2873 - val_accuracy: 0.6591 - 95ms/epoch - 12ms/step
# Epoch 64/100
# 8/8 - 0s - loss: 0.0897 - accuracy: 0.9929 - val_loss: 1.3014 - val_accuracy: 0.6705 - 104ms/epoch - 13ms/step
# Epoch 65/100
# 8/8 - 0s - loss: 0.0849 - accuracy: 0.9859 - val_loss: 1.3209 - val_accuracy: 0.6705 - 95ms/epoch - 12ms/step
# Epoch 66/100
# 8/8 - 0s - loss: 0.0783 - accuracy: 0.9901 - val_loss: 1.3279 - val_accuracy: 0.6591 - 95ms/epoch - 12ms/step
# Epoch 67/100
# 8/8 - 0s - loss: 0.0757 - accuracy: 0.9944 - val_loss: 1.3455 - val_accuracy: 0.6591 - 106ms/epoch - 13ms/step
# Epoch 68/100
# 8/8 - 0s - loss: 0.0712 - accuracy: 0.9958 - val_loss: 1.3868 - val_accuracy: 0.6705 - 94ms/epoch - 12ms/step
# Epoch 69/100
# 8/8 - 0s - loss: 0.0697 - accuracy: 0.9944 - val_loss: 1.4098 - val_accuracy: 0.6477 - 100ms/epoch - 12ms/step
# Epoch 70/100
# 8/8 - 0s - loss: 0.0676 - accuracy: 0.9972 - val_loss: 1.4414 - val_accuracy: 0.6818 - 105ms/epoch - 13ms/step
# Epoch 71/100
# 8/8 - 0s - loss: 0.0623 - accuracy: 0.9986 - val_loss: 1.4519 - val_accuracy: 0.6818 - 100ms/epoch - 13ms/step
# Epoch 72/100
# 8/8 - 0s - loss: 0.0601 - accuracy: 0.9986 - val_loss: 1.4385 - val_accuracy: 0.6705 - 97ms/epoch - 12ms/step
# Epoch 73/100
# 8/8 - 0s - loss: 0.0562 - accuracy: 1.0000 - val_loss: 1.4488 - val_accuracy: 0.6705 - 97ms/epoch - 12ms/step
# Epoch 74/100
# 8/8 - 0s - loss: 0.0523 - accuracy: 1.0000 - val_loss: 1.4647 - val_accuracy: 0.6591 - 105ms/epoch - 13ms/step
# Epoch 75/100
# 8/8 - 0s - loss: 0.0505 - accuracy: 1.0000 - val_loss: 1.4739 - val_accuracy: 0.6818 - 100ms/epoch - 13ms/step
# Epoch 76/100
# 8/8 - 0s - loss: 0.0486 - accuracy: 1.0000 - val_loss: 1.4667 - val_accuracy: 0.6818 - 111ms/epoch - 14ms/step
# Epoch 77/100
# 8/8 - 0s - loss: 0.0472 - accuracy: 1.0000 - val_loss: 1.4967 - val_accuracy: 0.6818 - 100ms/epoch - 13ms/step
# Epoch 78/100
# 8/8 - 0s - loss: 0.0448 - accuracy: 1.0000 - val_loss: 1.5189 - val_accuracy: 0.6932 - 100ms/epoch - 13ms/step
# Epoch 79/100
# 8/8 - 0s - loss: 0.0434 - accuracy: 1.0000 - val_loss: 1.5445 - val_accuracy: 0.6818 - 95ms/epoch - 12ms/step
# Epoch 80/100
# 8/8 - 0s - loss: 0.0413 - accuracy: 1.0000 - val_loss: 1.5726 - val_accuracy: 0.6818 - 95ms/epoch - 12ms/step
# Epoch 81/100
# 8/8 - 0s - loss: 0.0402 - accuracy: 1.0000 - val_loss: 1.5892 - val_accuracy: 0.6705 - 95ms/epoch - 12ms/step
# Epoch 82/100
# 8/8 - 0s - loss: 0.0405 - accuracy: 1.0000 - val_loss: 1.5683 - val_accuracy: 0.6477 - 93ms/epoch - 12ms/step
# Epoch 83/100
# 8/8 - 0s - loss: 0.0399 - accuracy: 1.0000 - val_loss: 1.6103 - val_accuracy: 0.6818 - 96ms/epoch - 12ms/step
# Epoch 84/100
# 8/8 - 0s - loss: 0.0373 - accuracy: 1.0000 - val_loss: 1.6342 - val_accuracy: 0.6818 - 95ms/epoch - 12ms/step
# Epoch 85/100
# 8/8 - 0s - loss: 0.0350 - accuracy: 1.0000 - val_loss: 1.6439 - val_accuracy: 0.6705 - 105ms/epoch - 13ms/step
# Epoch 86/100
# 8/8 - 0s - loss: 0.0352 - accuracy: 0.9986 - val_loss: 1.6646 - val_accuracy: 0.6818 - 95ms/epoch - 12ms/step
# Epoch 87/100
# 8/8 - 0s - loss: 0.0336 - accuracy: 1.0000 - val_loss: 1.6708 - val_accuracy: 0.6818 - 93ms/epoch - 12ms/step
# Epoch 88/100
# 8/8 - 0s - loss: 0.0322 - accuracy: 1.0000 - val_loss: 1.6967 - val_accuracy: 0.6818 - 93ms/epoch - 12ms/step
# Epoch 89/100
# 8/8 - 0s - loss: 0.0312 - accuracy: 1.0000 - val_loss: 1.7081 - val_accuracy: 0.6705 - 97ms/epoch - 12ms/step
# Epoch 90/100
# 8/8 - 0s - loss: 0.0298 - accuracy: 1.0000 - val_loss: 1.7030 - val_accuracy: 0.6705 - 100ms/epoch - 13ms/step
# Epoch 91/100
# 8/8 - 0s - loss: 0.0286 - accuracy: 1.0000 - val_loss: 1.7211 - val_accuracy: 0.6591 - 95ms/epoch - 12ms/step
# Epoch 92/100
# 8/8 - 0s - loss: 0.0273 - accuracy: 1.0000 - val_loss: 1.7378 - val_accuracy: 0.6591 - 89ms/epoch - 11ms/step
# Epoch 93/100
# 8/8 - 0s - loss: 0.0264 - accuracy: 1.0000 - val_loss: 1.7582 - val_accuracy: 0.6591 - 98ms/epoch - 12ms/step
# Epoch 94/100
# 8/8 - 0s - loss: 0.0257 - accuracy: 1.0000 - val_loss: 1.7825 - val_accuracy: 0.6591 - 96ms/epoch - 12ms/step
# Epoch 95/100
# 8/8 - 0s - loss: 0.0254 - accuracy: 1.0000 - val_loss: 1.7931 - val_accuracy: 0.6591 - 105ms/epoch - 13ms/step
# Epoch 96/100
# 8/8 - 0s - loss: 0.0244 - accuracy: 1.0000 - val_loss: 1.8029 - val_accuracy: 0.6591 - 102ms/epoch - 13ms/step
# Epoch 97/100
# 8/8 - 0s - loss: 0.0236 - accuracy: 1.0000 - val_loss: 1.8276 - val_accuracy: 0.6705 - 94ms/epoch - 12ms/step
# Epoch 98/100
# 8/8 - 0s - loss: 0.0231 - accuracy: 1.0000 - val_loss: 1.8349 - val_accuracy: 0.6705 - 96ms/epoch - 12ms/step
# Epoch 99/100
# 8/8 - 0s - loss: 0.0231 - accuracy: 1.0000 - val_loss: 1.8592 - val_accuracy: 0.6705 - 96ms/epoch - 12ms/step
# Epoch 100/100
# 8/8 - 0s - loss: 0.0221 - accuracy: 1.0000 - val_loss: 1.8752 - val_accuracy: 0.6818 - 102ms/epoch - 13ms/step

# %% [markdown]
# ## NN-Testing

# %%
test_loss, test_accuracy = model.evaluate(test_input, test_target)
print("The test loss: {0:.2f}, and the test accuracy: {1:.2f}".format(test_loss, test_accuracy))
# Out:
# 3/3 [==============================] - 0s 4ms/step - loss: 1.7461 - accuracy: 0.5843
# The test loss: 1.75, and the test accuracy: 0.58

# %% [markdown]
# #### The average NN-testig is 62%
# #### The model created by netural network is overfitting,and one of the possible reason is the dataset is small

# %% [markdown]
# ## Scikit-Learn LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression

# %%
classifier = LogisticRegression()
classifier.fit(scaled_input_data, shuffled_target_data)
# Out:
# LogisticRegression()

# %%
test_output = classifier.predict(test_input)

# %% [markdown]
# ### Confusion matrix

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_target,test_output)

# %%
cm_table = pd.DataFrame(cm)
cm_table.columns = ['Predict died', 'Predict euthanized', 'Predict lived']
cm_table = cm_table.rename({0: 'predict died', 1: 'Predict euthanized', 2: 'Predict lived'})
cm_table
# Out:
#                     Predict died  Predict euthanized  Predict lived
# predict died                  26                   3              4
# Predict euthanized             2                  17              5
# Predict lived                  3                   7             22

# %% [markdown]
# ### Sklearn test accuracy

# %%
from sklearn import metrics
test_accuracy = metrics.accuracy_score(test_output, test_target)
print('The test accuracy is {0:.2f}%'.format(test_accuracy*100))
# Out:
# The test accuracy is 73.03%

# %% [markdown]
# #### The average sklearn test accuracy is 70%

# %% [markdown]
# ## Loading Test dataset

# %%
test_data = pd.read_csv('test.csv')

# %%
horse_id = test_data['id']
test_input_predict = test_data.iloc[:, 1:]
test_input_predict = test_input_predict.drop('hospital_number', axis=1)

# %%
test_nan_cols = getNan_cols(test_input_predict.isnull().sum())
test_describe = test_input_predict.describe(include='all')

# %%
test_input_predict = categorical_fillNan(test_nan_cols, test_input_predict, test_describe)

# %%
test_dummies_input = pd.get_dummies(test_input_predict, dtype=int, drop_first=True)

# %%
def insertMissing_cols(dummies_input_data, test_input_predict):
    col_train = list(dummies_input_data.columns)
    col_test = list(test_input_predict.columns)
    missed_cols=[]
    
    for i in col_train:
        counts = col_test.count(i)
        if counts == 0:
            missed_cols.append(i)
    
    for i in missed_cols:
        test_input_predict[i] = 0
    
    return test_input_predict

# %%
def findExtra_cols(dummies_input_data, test_input_predict):
    col_train = list(dummies_input_data.columns)
    col_test = list(test_input_predict.columns)
    extra_cols=[]
    
    for i in col_test:
        counts = col_train.count(i)
        if counts == 0:
            extra_cols.append(i)
    
    for i in extra_cols:
        test_input_predict = test_input_predict.drop(i, axis=1)
        
    return test_input_predict

# %%
test_dummies_input = insertMissing_cols(dummies_input_data.copy(), test_dummies_input.copy())
test_dummies_input = findExtra_cols(dummies_input_data.copy(), test_dummies_input.copy())

# %%
print(test_dummies_input.shape)
# Out:
# (824, 54)

# %%
print(dummies_input_data.shape)
# Out:
# (1534, 54)

# %%
scaler.fit(test_dummies_input)
scaled_test_input = scaler.transform(test_dummies_input)

# %% [markdown]
# ## Sklearn model predict test dataset

# %%
sklearn_test_output = classifier.predict(scaled_test_input)

# %%
sklearn_df = pd.DataFrame({'id': horse_id, 'outcome': sklearn_test_output})
sklearn_df['outcome'] = sklearn_df['outcome'].map({0: 'died', 1: 'euthanized', 2: 'lived'})

# %%
sklearn_df
# Out:
#        id     outcome
# 0    1235       lived
# 1    1236       lived
# 2    1237       lived
# 3    1238  euthanized
# 4    1239       lived
# 5    1240        died
# 6    1241       lived
# 7    1242  euthanized
# 8    1243       lived
# 9    1244        died
# 10   1245        died
# 11   1246       lived
# 12   1247       lived
# 13   1248  euthanized
# 14   1249       lived
# 15   1250        died
# 16   1251       lived
# 17   1252  euthanized
# 18   1253        died
# 19   1254        died
# 20   1255        died
# 21   1256        died
# 22   1257        died
# 23   1258        died
# 24   1259  euthanized
# 25   1260  euthanized
# 26   1261        died
# 27   1262  euthanized
# 28   1263  euthanized
# 29   1264  euthanized
# 30   1265       lived
# 31   1266  euthanized
# 32   1267        died
# 33   1268       lived
# 34   1269        died
# 35   1270        died
# 36   1271        died
# 37   1272       lived
# 38   1273        died
# 39   1274       lived
# 40   1275  euthanized
# 41   1276       lived
# 42   1277  euthanized
# 43   1278       lived
# 44   1279  euthanized
# 45   1280        died
# 46   1281        died
# 47   1282        died
# 48   1283       lived
# 49   1284        died
# 50   1285  euthanized
# 51   1286       lived
# 52   1287        died
# 53   1288        died
# 54   1289        died
# 55   1290       lived
# 56   1291        died
# 57   1292        died
# 58   1293        died
# 59   1294        died
# 60   1295        died
# 61   1296  euthanized
# 62   1297       lived
# 63   1298        died
# 64   1299  euthanized
# 65   1300  euthanized
# 66   1301  euthanized
# 67   1302  euthanized
# 68   1303       lived
# 69   1304       lived
# 70   1305        died
# 71   1306  euthanized
# 72   1307        died
# 73   1308       lived
# 74   1309  euthanized
# 75   1310        died
# 76   1311  euthanized
# 77   1312       lived
# 78   1313        died
# 79   1314  euthanized
# 80   1315  euthanized
# 81   1316  euthanized
# 82   1317       lived
# 83   1318       lived
# 84   1319       lived
# 85   1320       lived
# 86   1321        died
# 87   1322  euthanized
# 88   1323  euthanized
# 89   1324       lived
# 90   1325  euthanized
# 91   1326        died
# 92   1327  euthanized
# 93   1328       lived
# 94   1329       lived
# 95   1330       lived
# 96   1331  euthanized
# 97   1332  euthanized
# 98   1333        died
# 99   1334  euthanized
# 100  1335  euthanized
# 101  1336        died
# 102  1337  euthanized
# 103  1338       lived
# 104  1339  euthanized
# 105  1340       lived
# 106  1341        died
# 107  1342  euthanized
# 108  1343       lived
# 109  1344        died
# 110  1345        died
# 111  1346  euthanized
# 112  1347        died
# 113  1348       lived
# 114  1349       lived
# 115  1350  euthanized
# 116  1351       lived
# 117  1352        died
# 118  1353        died
# 119  1354  euthanized
# 120  1355       lived
# 121  1356       lived
# 122  1357       lived
# 123  1358       lived
# 124  1359       lived
# 125  1360       lived
# 126  1361        died
# 127  1362       lived
# 128  1363  euthanized
# 129  1364        died
# 130  1365       lived
# 131  1366       lived
# 132  1367        died
# 133  1368       lived
# 134  1369        died
# 135  1370       lived
# 136  1371       lived
# 137  1372  euthanized
# 138  1373       lived
# 139  1374       lived
# 140  1375  euthanized
# 141  1376        died
# 142  1377       lived
# 143  1378  euthanized
# 144  1379  euthanized
# 145  1380       lived
# 146  1381        died
# 147  1382        died
# 148  1383       lived
# 149  1384  euthanized
# 150  1385        died
# 151  1386  euthanized
# 152  1387       lived
# 153  1388       lived
# 154  1389       lived
# 155  1390       lived
# 156  1391  euthanized
# 157  1392  euthanized
# 158  1393        died
# 159  1394       lived
# 160  1395       lived
# 161  1396        died
# 162  1397       lived
# 163  1398  euthanized
# 164  1399  euthanized
# 165  1400  euthanized
# 166  1401       lived
# 167  1402  euthanized
# 168  1403  euthanized
# 169  1404       lived
# 170  1405       lived
# 171  1406       lived
# 172  1407  euthanized
# 173  1408       lived
# 174  1409        died
# 175  1410  euthanized
# 176  1411        died
# 177  1412  euthanized
# 178  1413  euthanized
# 179  1414       lived
# 180  1415  euthanized
# 181  1416       lived
# 182  1417       lived
# 183  1418       lived
# 184  1419        died
# 185  1420        died
# 186  1421        died
# 187  1422        died
# 188  1423       lived
# 189  1424       lived
# 190  1425  euthanized
# 191  1426  euthanized
# 192  1427        died
# 193  1428        died
# 194  1429       lived
# 195  1430  euthanized
# 196  1431        died
# 197  1432       lived
# 198  1433        died
# 199  1434        died
# 200  1435        died
# 201  1436       lived
# 202  1437       lived
# 203  1438  euthanized
# 204  1439  euthanized
# 205  1440  euthanized
# 206  1441       lived
# 207  1442        died
# 208  1443       lived
# 209  1444        died
# 210  1445        died
# 211  1446  euthanized
# 212  1447        died
# 213  1448       lived
# 214  1449  euthanized
# 215  1450  euthanized
# 216  1451       lived
# 217  1452  euthanized
# 218  1453  euthanized
# 219  1454       lived
# 220  1455  euthanized
# 221  1456  euthanized
# 222  1457  euthanized
# 223  1458        died
# 224  1459        died
# 225  1460       lived
# 226  1461        died
# 227  1462       lived
# 228  1463        died
# 229  1464       lived
# 230  1465       lived
# 231  1466       lived
# 232  1467  euthanized
# 233  1468       lived
# 234  1469        died
# 235  1470  euthanized
# 236  1471  euthanized
# 237  1472        died
# 238  1473        died
# 239  1474  euthanized
# 240  1475        died
# 241  1476  euthanized
# 242  1477       lived
# 243  1478  euthanized
# 244  1479       lived
# 245  1480  euthanized
# 246  1481        died
# 247  1482        died
# 248  1483  euthanized
# 249  1484       lived
# 250  1485  euthanized
# 251  1486  euthanized
# 252  1487        died
# 253  1488       lived
# 254  1489        died
# 255  1490        died
# 256  1491       lived
# 257  1492  euthanized
# 258  1493       lived
# 259  1494       lived
# 260  1495  euthanized
# 261  1496        died
# 262  1497  euthanized
# 263  1498        died
# 264  1499  euthanized
# 265  1500       lived
# 266  1501       lived
# 267  1502        died
# 268  1503       lived
# 269  1504       lived
# 270  1505       lived
# 271  1506  euthanized
# 272  1507  euthanized
# 273  1508       lived
# 274  1509       lived
# 275  1510       lived
# 276  1511  euthanized
# 277  1512  euthanized
# 278  1513        died
# 279  1514  euthanized
# 280  1515  euthanized
# 281  1516       lived
# 282  1517        died
# 283  1518        died
# 284  1519  euthanized
# 285  1520  euthanized
# 286  1521       lived
# 287  1522        died
# 288  1523       lived
# 289  1524        died
# 290  1525        died
# 291  1526  euthanized
# 292  1527        died
# 293  1528       lived
# 294  1529        died
# 295  1530        died
# 296  1531       lived
# 297  1532        died
# 298  1533  euthanized
# 299  1534        died
# 300  1535       lived
# 301  1536        died
# 302  1537  euthanized
# 303  1538       lived
# 304  1539  euthanized
# 305  1540       lived
# 306  1541  euthanized
# 307  1542  euthanized
# 308  1543  euthanized
# 309  1544        died
# 310  1545       lived
# 311  1546       lived
# 312  1547        died
# 313  1548        died
# 314  1549       lived
# 315  1550        died
# 316  1551       lived
# 317  1552        died
# 318  1553       lived
# 319  1554       lived
# 320  1555        died
# 321  1556  euthanized
# 322  1557       lived
# 323  1558       lived
# 324  1559        died
# 325  1560        died
# 326  1561        died
# 327  1562       lived
# 328  1563        died
# 329  1564  euthanized
# 330  1565       lived
# 331  1566       lived
# 332  1567       lived
# 333  1568        died
# 334  1569  euthanized
# 335  1570  euthanized
# 336  1571  euthanized
# 337  1572       lived
# 338  1573       lived
# 339  1574       lived
# 340  1575       lived
# 341  1576       lived
# 342  1577        died
# 343  1578       lived
# 344  1579        died
# 345  1580  euthanized
# 346  1581       lived
# 347  1582        died
# 348  1583       lived
# 349  1584       lived
# 350  1585  euthanized
# 351  1586  euthanized
# 352  1587       lived
# 353  1588        died
# 354  1589  euthanized
# 355  1590  euthanized
# 356  1591       lived
# 357  1592       lived
# 358  1593        died
# 359  1594        died
# 360  1595        died
# 361  1596  euthanized
# 362  1597  euthanized
# 363  1598       lived
# 364  1599       lived
# 365  1600  euthanized
# 366  1601        died
# 367  1602       lived
# 368  1603  euthanized
# 369  1604        died
# 370  1605        died
# 371  1606       lived
# 372  1607       lived
# 373  1608        died
# 374  1609       lived
# 375  1610  euthanized
# 376  1611       lived
# 377  1612        died
# 378  1613       lived
# 379  1614       lived
# 380  1615        died
# 381  1616  euthanized
# 382  1617       lived
# 383  1618        died
# 384  1619       lived
# 385  1620       lived
# 386  1621        died
# 387  1622        died
# 388  1623        died
# 389  1624       lived
# 390  1625        died
# 391  1626        died
# 392  1627  euthanized
# 393  1628  euthanized
# 394  1629        died
# 395  1630  euthanized
# 396  1631       lived
# 397  1632  euthanized
# 398  1633       lived
# 399  1634        died
# 400  1635       lived
# 401  1636       lived
# 402  1637        died
# 403  1638        died
# 404  1639  euthanized
# 405  1640        died
# 406  1641  euthanized
# 407  1642       lived
# 408  1643  euthanized
# 409  1644  euthanized
# 410  1645       lived
# 411  1646  euthanized
# 412  1647        died
# 413  1648        died
# 414  1649  euthanized
# 415  1650        died
# 416  1651  euthanized
# 417  1652        died
# 418  1653       lived
# 419  1654  euthanized
# 420  1655       lived
# 421  1656        died
# 422  1657        died
# 423  1658        died
# 424  1659  euthanized
# 425  1660        died
# 426  1661  euthanized
# 427  1662  euthanized
# 428  1663        died
# 429  1664       lived
# 430  1665       lived
# 431  1666       lived
# 432  1667        died
# 433  1668  euthanized
# 434  1669       lived
# 435  1670        died
# 436  1671       lived
# 437  1672       lived
# 438  1673       lived
# 439  1674  euthanized
# 440  1675        died
# 441  1676  euthanized
# 442  1677       lived
# 443  1678  euthanized
# 444  1679  euthanized
# 445  1680        died
# 446  1681  euthanized
# 447  1682        died
# 448  1683        died
# 449  1684  euthanized
# 450  1685  euthanized
# 451  1686       lived
# 452  1687  euthanized
# 453  1688        died
# 454  1689  euthanized
# 455  1690       lived
# 456  1691       lived
# 457  1692       lived
# 458  1693        died
# 459  1694       lived
# 460  1695       lived
# 461  1696  euthanized
# 462  1697  euthanized
# 463  1698  euthanized
# 464  1699       lived
# 465  1700  euthanized
# 466  1701  euthanized
# 467  1702       lived
# 468  1703  euthanized
# 469  1704        died
# 470  1705       lived
# 471  1706        died
# 472  1707        died
# 473  1708  euthanized
# 474  1709       lived
# 475  1710        died
# 476  1711       lived
# 477  1712       lived
# 478  1713        died
# 479  1714  euthanized
# 480  1715        died
# 481  1716  euthanized
# 482  1717       lived
# 483  1718       lived
# 484  1719       lived
# 485  1720        died
# 486  1721  euthanized
# 487  1722       lived
# 488  1723        died
# 489  1724  euthanized
# 490  1725        died
# 491  1726        died
# 492  1727       lived
# 493  1728       lived
# 494  1729       lived
# 495  1730        died
# 496  1731        died
# 497  1732  euthanized
# 498  1733        died
# 499  1734  euthanized
# 500  1735  euthanized
# 501  1736       lived
# 502  1737       lived
# 503  1738  euthanized
# 504  1739       lived
# 505  1740        died
# 506  1741        died
# 507  1742       lived
# 508  1743        died
# 509  1744        died
# 510  1745        died
# 511  1746        died
# 512  1747       lived
# 513  1748  euthanized
# 514  1749       lived
# 515  1750       lived
# 516  1751  euthanized
# 517  1752       lived
# 518  1753        died
# 519  1754       lived
# 520  1755        died
# 521  1756  euthanized
# 522  1757  euthanized
# 523  1758        died
# 524  1759       lived
# 525  1760        died
# 526  1761        died
# 527  1762  euthanized
# 528  1763       lived
# 529  1764  euthanized
# 530  1765  euthanized
# 531  1766  euthanized
# 532  1767  euthanized
# 533  1768  euthanized
# 534  1769        died
# 535  1770        died
# 536  1771       lived
# 537  1772        died
# 538  1773       lived
# 539  1774       lived
# 540  1775        died
# 541  1776        died
# 542  1777  euthanized
# 543  1778        died
# 544  1779  euthanized
# 545  1780  euthanized
# 546  1781  euthanized
# 547  1782  euthanized
# 548  1783       lived
# 549  1784        died
# 550  1785  euthanized
# 551  1786  euthanized
# 552  1787        died
# 553  1788  euthanized
# 554  1789       lived
# 555  1790  euthanized
# 556  1791        died
# 557  1792        died
# 558  1793  euthanized
# 559  1794       lived
# 560  1795  euthanized
# 561  1796  euthanized
# 562  1797  euthanized
# 563  1798        died
# 564  1799  euthanized
# 565  1800        died
# 566  1801       lived
# 567  1802        died
# 568  1803        died
# 569  1804  euthanized
# 570  1805  euthanized
# 571  1806  euthanized
# 572  1807  euthanized
# 573  1808  euthanized
# 574  1809       lived
# 575  1810  euthanized
# 576  1811  euthanized
# 577  1812  euthanized
# 578  1813        died
# 579  1814  euthanized
# 580  1815  euthanized
# 581  1816       lived
# 582  1817       lived
# 583  1818       lived
# 584  1819  euthanized
# 585  1820       lived
# 586  1821       lived
# 587  1822       lived
# 588  1823       lived
# 589  1824  euthanized
# 590  1825  euthanized
# 591  1826       lived
# 592  1827  euthanized
# 593  1828       lived
# 594  1829  euthanized
# 595  1830       lived
# 596  1831       lived
# 597  1832  euthanized
# 598  1833        died
# 599  1834  euthanized
# 600  1835  euthanized
# 601  1836  euthanized
# 602  1837  euthanized
# 603  1838  euthanized
# 604  1839        died
# 605  1840  euthanized
# 606  1841       lived
# 607  1842       lived
# 608  1843       lived
# 609  1844        died
# 610  1845  euthanized
# 611  1846       lived
# 612  1847        died
# 613  1848       lived
# 614  1849  euthanized
# 615  1850        died
# 616  1851  euthanized
# 617  1852       lived
# 618  1853       lived
# 619  1854        died
# 620  1855        died
# 621  1856        died
# 622  1857        died
# 623  1858  euthanized
# 624  1859  euthanized
# 625  1860       lived
# 626  1861  euthanized
# 627  1862        died
# 628  1863  euthanized
# 629  1864       lived
# 630  1865        died
# 631  1866        died
# 632  1867       lived
# 633  1868        died
# 634  1869        died
# 635  1870        died
# 636  1871        died
# 637  1872  euthanized
# 638  1873        died
# 639  1874        died
# 640  1875  euthanized
# 641  1876       lived
# 642  1877  euthanized
# 643  1878       lived
# 644  1879        died
# 645  1880        died
# 646  1881        died
# 647  1882       lived
# 648  1883       lived
# 649  1884  euthanized
# 650  1885  euthanized
# 651  1886  euthanized
# 652  1887        died
# 653  1888  euthanized
# 654  1889  euthanized
# 655  1890       lived
# 656  1891  euthanized
# 657  1892  euthanized
# 658  1893       lived
# 659  1894       lived
# 660  1895        died
# 661  1896       lived
# 662  1897  euthanized
# 663  1898       lived
# 664  1899       lived
# 665  1900  euthanized
# 666  1901        died
# 667  1902  euthanized
# 668  1903        died
# 669  1904       lived
# 670  1905  euthanized
# 671  1906  euthanized
# 672  1907        died
# 673  1908  euthanized
# 674  1909  euthanized
# 675  1910        died
# 676  1911       lived
# 677  1912       lived
# 678  1913       lived
# 679  1914       lived
# 680  1915  euthanized
# 681  1916  euthanized
# 682  1917        died
# 683  1918       lived
# 684  1919       lived
# 685  1920       lived
# 686  1921       lived
# 687  1922        died
# 688  1923  euthanized
# 689  1924  euthanized
# 690  1925        died
# 691  1926  euthanized
# 692  1927        died
# 693  1928       lived
# 694  1929  euthanized
# 695  1930        died
# 696  1931        died
# 697  1932       lived
# 698  1933       lived
# 699  1934  euthanized
# 700  1935        died
# 701  1936       lived
# 702  1937       lived
# 703  1938  euthanized
# 704  1939       lived
# 705  1940       lived
# 706  1941  euthanized
# 707  1942        died
# 708  1943  euthanized
# 709  1944       lived
# 710  1945  euthanized
# 711  1946  euthanized
# 712  1947        died
# 713  1948  euthanized
# 714  1949        died
# 715  1950  euthanized
# 716  1951  euthanized
# 717  1952  euthanized
# 718  1953        died
# 719  1954        died
# 720  1955        died
# 721  1956        died
# 722  1957       lived
# 723  1958       lived
# 724  1959       lived
# 725  1960        died
# 726  1961        died
# 727  1962       lived
# 728  1963        died
# 729  1964        died
# 730  1965       lived
# 731  1966        died
# 732  1967       lived
# 733  1968  euthanized
# 734  1969       lived
# 735  1970        died
# 736  1971       lived
# 737  1972  euthanized
# 738  1973  euthanized
# 739  1974       lived
# 740  1975  euthanized
# 741  1976        died
# 742  1977  euthanized
# 743  1978       lived
# 744  1979        died
# 745  1980  euthanized
# 746  1981  euthanized
# 747  1982  euthanized
# 748  1983       lived
# 749  1984  euthanized
# 750  1985        died
# 751  1986  euthanized
# 752  1987        died
# 753  1988  euthanized
# 754  1989  euthanized
# 755  1990        died
# 756  1991       lived
# 757  1992       lived
# 758  1993       lived
# 759  1994        died
# 760  1995        died
# 761  1996        died
# 762  1997        died
# 763  1998  euthanized
# 764  1999        died
# 765  2000  euthanized
# 766  2001        died
# 767  2002       lived
# 768  2003       lived
# 769  2004  euthanized
# 770  2005        died
# 771  2006       lived
# 772  2007       lived
# 773  2008        died
# 774  2009       lived
# 775  2010  euthanized
# 776  2011        died
# 777  2012  euthanized
# 778  2013  euthanized
# 779  2014       lived
# 780  2015       lived
# 781  2016       lived
# 782  2017  euthanized
# 783  2018       lived
# 784  2019       lived
# 785  2020       lived
# 786  2021  euthanized
# 787  2022        died
# 788  2023       lived
# 789  2024  euthanized
# 790  2025        died
# 791  2026  euthanized
# 792  2027  euthanized
# 793  2028       lived
# 794  2029       lived
# 795  2030       lived
# 796  2031  euthanized
# 797  2032  euthanized
# 798  2033  euthanized
# 799  2034       lived
# 800  2035        died
# 801  2036       lived
# 802  2037       lived
# 803  2038        died
# 804  2039  euthanized
# 805  2040       lived
# 806  2041        died
# 807  2042        died
# 808  2043       lived
# 809  2044  euthanized
# 810  2045  euthanized
# 811  2046        died
# 812  2047       lived
# 813  2048       lived
# 814  2049  euthanized
# 815  2050  euthanized
# 816  2051  euthanized
# 817  2052        died
# 818  2053        died
# 819  2054  euthanized
# 820  2055       lived
# 821  2056  euthanized
# 822  2057        died
# 823  2058       lived

# %% [markdown]
# ## Deep learning model predict test dataset

# %%
NN_test_accuracy_output = model.predict(scaled_test_input)
# Out:
# 26/26 [==============================] - 0s 3ms/step

# %%
NN_test_accuracy_output = NN_test_accuracy_output.round(2)

# %%
def convertAccuracy_toStr(NN_test_output):
    test_output=[]
    
    for i in NN_test_output:
        max_value = max(i)
        index = np.where(i == max_value)
        index = index[0][0]
        
        if index == 0:
            test_output.append('died')
        elif index == 1:
            test_output.append('euthanized')
        else:
            test_output.append('lived')
            
    return test_output

# %%
NN_test_str_output = convertAccuracy_toStr(NN_test_accuracy_output)

# %%
NN_df = pd.DataFrame({'id': horse_id, 'outcome': NN_test_str_output})

# %%
NN_df
# Out:
#        id     outcome
# 0    1235       lived
# 1    1236        died
# 2    1237       lived
# 3    1238  euthanized
# 4    1239       lived
# 5    1240        died
# 6    1241       lived
# 7    1242        died
# 8    1243       lived
# 9    1244       lived
# 10   1245        died
# 11   1246       lived
# 12   1247  euthanized
# 13   1248  euthanized
# 14   1249       lived
# 15   1250        died
# 16   1251       lived
# 17   1252        died
# 18   1253  euthanized
# 19   1254        died
# 20   1255  euthanized
# 21   1256        died
# 22   1257  euthanized
# 23   1258        died
# 24   1259        died
# 25   1260       lived
# 26   1261        died
# 27   1262  euthanized
# 28   1263  euthanized
# 29   1264  euthanized
# 30   1265  euthanized
# 31   1266  euthanized
# 32   1267        died
# 33   1268        died
# 34   1269       lived
# 35   1270  euthanized
# 36   1271        died
# 37   1272       lived
# 38   1273        died
# 39   1274       lived
# 40   1275  euthanized
# 41   1276        died
# 42   1277  euthanized
# 43   1278  euthanized
# 44   1279  euthanized
# 45   1280        died
# 46   1281  euthanized
# 47   1282  euthanized
# 48   1283       lived
# 49   1284        died
# 50   1285  euthanized
# 51   1286       lived
# 52   1287        died
# 53   1288  euthanized
# 54   1289       lived
# 55   1290       lived
# 56   1291        died
# 57   1292        died
# 58   1293  euthanized
# 59   1294        died
# 60   1295        died
# 61   1296  euthanized
# 62   1297        died
# 63   1298        died
# 64   1299        died
# 65   1300       lived
# 66   1301  euthanized
# 67   1302  euthanized
# 68   1303       lived
# 69   1304       lived
# 70   1305  euthanized
# 71   1306  euthanized
# 72   1307        died
# 73   1308       lived
# 74   1309  euthanized
# 75   1310        died
# 76   1311  euthanized
# 77   1312       lived
# 78   1313        died
# 79   1314  euthanized
# 80   1315  euthanized
# 81   1316  euthanized
# 82   1317       lived
# 83   1318  euthanized
# 84   1319       lived
# 85   1320       lived
# 86   1321        died
# 87   1322  euthanized
# 88   1323  euthanized
# 89   1324       lived
# 90   1325  euthanized
# 91   1326       lived
# 92   1327        died
# 93   1328  euthanized
# 94   1329  euthanized
# 95   1330       lived
# 96   1331  euthanized
# 97   1332  euthanized
# 98   1333       lived
# 99   1334  euthanized
# 100  1335  euthanized
# 101  1336       lived
# 102  1337        died
# 103  1338       lived
# 104  1339  euthanized
# 105  1340       lived
# 106  1341        died
# 107  1342  euthanized
# 108  1343       lived
# 109  1344       lived
# 110  1345        died
# 111  1346  euthanized
# 112  1347  euthanized
# 113  1348       lived
# 114  1349       lived
# 115  1350  euthanized
# 116  1351  euthanized
# 117  1352        died
# 118  1353        died
# 119  1354  euthanized
# 120  1355       lived
# 121  1356       lived
# 122  1357  euthanized
# 123  1358       lived
# 124  1359       lived
# 125  1360       lived
# 126  1361        died
# 127  1362       lived
# 128  1363  euthanized
# 129  1364       lived
# 130  1365       lived
# 131  1366       lived
# 132  1367        died
# 133  1368       lived
# 134  1369        died
# 135  1370  euthanized
# 136  1371       lived
# 137  1372  euthanized
# 138  1373        died
# 139  1374       lived
# 140  1375  euthanized
# 141  1376       lived
# 142  1377       lived
# 143  1378        died
# 144  1379  euthanized
# 145  1380  euthanized
# 146  1381       lived
# 147  1382        died
# 148  1383        died
# 149  1384  euthanized
# 150  1385        died
# 151  1386  euthanized
# 152  1387       lived
# 153  1388       lived
# 154  1389       lived
# 155  1390       lived
# 156  1391  euthanized
# 157  1392        died
# 158  1393        died
# 159  1394  euthanized
# 160  1395       lived
# 161  1396  euthanized
# 162  1397       lived
# 163  1398  euthanized
# 164  1399  euthanized
# 165  1400  euthanized
# 166  1401       lived
# 167  1402       lived
# 168  1403  euthanized
# 169  1404       lived
# 170  1405       lived
# 171  1406  euthanized
# 172  1407        died
# 173  1408       lived
# 174  1409       lived
# 175  1410  euthanized
# 176  1411        died
# 177  1412  euthanized
# 178  1413        died
# 179  1414       lived
# 180  1415  euthanized
# 181  1416  euthanized
# 182  1417       lived
# 183  1418       lived
# 184  1419        died
# 185  1420        died
# 186  1421       lived
# 187  1422  euthanized
# 188  1423  euthanized
# 189  1424  euthanized
# 190  1425       lived
# 191  1426        died
# 192  1427        died
# 193  1428        died
# 194  1429  euthanized
# 195  1430        died
# 196  1431        died
# 197  1432       lived
# 198  1433        died
# 199  1434        died
# 200  1435        died
# 201  1436  euthanized
# 202  1437  euthanized
# 203  1438  euthanized
# 204  1439  euthanized
# 205  1440       lived
# 206  1441  euthanized
# 207  1442        died
# 208  1443  euthanized
# 209  1444        died
# 210  1445        died
# 211  1446       lived
# 212  1447        died
# 213  1448       lived
# 214  1449  euthanized
# 215  1450  euthanized
# 216  1451       lived
# 217  1452  euthanized
# 218  1453        died
# 219  1454        died
# 220  1455        died
# 221  1456  euthanized
# 222  1457  euthanized
# 223  1458        died
# 224  1459  euthanized
# 225  1460        died
# 226  1461        died
# 227  1462  euthanized
# 228  1463  euthanized
# 229  1464       lived
# 230  1465       lived
# 231  1466       lived
# 232  1467  euthanized
# 233  1468  euthanized
# 234  1469        died
# 235  1470       lived
# 236  1471       lived
# 237  1472        died
# 238  1473        died
# 239  1474        died
# 240  1475  euthanized
# 241  1476  euthanized
# 242  1477  euthanized
# 243  1478  euthanized
# 244  1479       lived
# 245  1480       lived
# 246  1481  euthanized
# 247  1482        died
# 248  1483  euthanized
# 249  1484       lived
# 250  1485  euthanized
# 251  1486  euthanized
# 252  1487        died
# 253  1488  euthanized
# 254  1489        died
# 255  1490  euthanized
# 256  1491       lived
# 257  1492       lived
# 258  1493  euthanized
# 259  1494       lived
# 260  1495  euthanized
# 261  1496        died
# 262  1497  euthanized
# 263  1498        died
# 264  1499        died
# 265  1500  euthanized
# 266  1501       lived
# 267  1502       lived
# 268  1503       lived
# 269  1504  euthanized
# 270  1505  euthanized
# 271  1506  euthanized
# 272  1507  euthanized
# 273  1508        died
# 274  1509       lived
# 275  1510       lived
# 276  1511  euthanized
# 277  1512  euthanized
# 278  1513        died
# 279  1514  euthanized
# 280  1515  euthanized
# 281  1516  euthanized
# 282  1517  euthanized
# 283  1518        died
# 284  1519        died
# 285  1520        died
# 286  1521       lived
# 287  1522        died
# 288  1523  euthanized
# 289  1524        died
# 290  1525       lived
# 291  1526  euthanized
# 292  1527       lived
# 293  1528  euthanized
# 294  1529  euthanized
# 295  1530        died
# 296  1531       lived
# 297  1532  euthanized
# 298  1533        died
# 299  1534       lived
# 300  1535  euthanized
# 301  1536  euthanized
# 302  1537  euthanized
# 303  1538       lived
# 304  1539  euthanized
# 305  1540  euthanized
# 306  1541  euthanized
# 307  1542  euthanized
# 308  1543  euthanized
# 309  1544        died
# 310  1545  euthanized
# 311  1546       lived
# 312  1547        died
# 313  1548        died
# 314  1549       lived
# 315  1550       lived
# 316  1551       lived
# 317  1552       lived
# 318  1553       lived
# 319  1554       lived
# 320  1555        died
# 321  1556       lived
# 322  1557        died
# 323  1558  euthanized
# 324  1559        died
# 325  1560  euthanized
# 326  1561        died
# 327  1562        died
# 328  1563        died
# 329  1564  euthanized
# 330  1565  euthanized
# 331  1566       lived
# 332  1567       lived
# 333  1568        died
# 334  1569        died
# 335  1570        died
# 336  1571        died
# 337  1572       lived
# 338  1573       lived
# 339  1574       lived
# 340  1575       lived
# 341  1576       lived
# 342  1577        died
# 343  1578  euthanized
# 344  1579        died
# 345  1580       lived
# 346  1581       lived
# 347  1582        died
# 348  1583       lived
# 349  1584  euthanized
# 350  1585        died
# 351  1586  euthanized
# 352  1587       lived
# 353  1588        died
# 354  1589  euthanized
# 355  1590  euthanized
# 356  1591       lived
# 357  1592       lived
# 358  1593        died
# 359  1594        died
# 360  1595        died
# 361  1596  euthanized
# 362  1597  euthanized
# 363  1598        died
# 364  1599  euthanized
# 365  1600  euthanized
# 366  1601        died
# 367  1602       lived
# 368  1603       lived
# 369  1604       lived
# 370  1605        died
# 371  1606       lived
# 372  1607       lived
# 373  1608        died
# 374  1609       lived
# 375  1610  euthanized
# 376  1611  euthanized
# 377  1612        died
# 378  1613        died
# 379  1614  euthanized
# 380  1615        died
# 381  1616  euthanized
# 382  1617       lived
# 383  1618  euthanized
# 384  1619       lived
# 385  1620       lived
# 386  1621        died
# 387  1622        died
# 388  1623  euthanized
# 389  1624        died
# 390  1625        died
# 391  1626       lived
# 392  1627  euthanized
# 393  1628  euthanized
# 394  1629        died
# 395  1630  euthanized
# 396  1631       lived
# 397  1632        died
# 398  1633       lived
# 399  1634        died
# 400  1635  euthanized
# 401  1636       lived
# 402  1637       lived
# 403  1638       lived
# 404  1639  euthanized
# 405  1640        died
# 406  1641  euthanized
# 407  1642       lived
# 408  1643        died
# 409  1644  euthanized
# 410  1645       lived
# 411  1646  euthanized
# 412  1647        died
# 413  1648        died
# 414  1649       lived
# 415  1650        died
# 416  1651        died
# 417  1652        died
# 418  1653       lived
# 419  1654  euthanized
# 420  1655  euthanized
# 421  1656       lived
# 422  1657        died
# 423  1658        died
# 424  1659  euthanized
# 425  1660        died
# 426  1661        died
# 427  1662  euthanized
# 428  1663       lived
# 429  1664        died
# 430  1665        died
# 431  1666  euthanized
# 432  1667        died
# 433  1668  euthanized
# 434  1669       lived
# 435  1670        died
# 436  1671        died
# 437  1672       lived
# 438  1673       lived
# 439  1674        died
# 440  1675        died
# 441  1676  euthanized
# 442  1677       lived
# 443  1678        died
# 444  1679  euthanized
# 445  1680       lived
# 446  1681  euthanized
# 447  1682        died
# 448  1683  euthanized
# 449  1684  euthanized
# 450  1685  euthanized
# 451  1686  euthanized
# 452  1687  euthanized
# 453  1688        died
# 454  1689  euthanized
# 455  1690       lived
# 456  1691  euthanized
# 457  1692       lived
# 458  1693        died
# 459  1694       lived
# 460  1695       lived
# 461  1696       lived
# 462  1697  euthanized
# 463  1698        died
# 464  1699  euthanized
# 465  1700  euthanized
# 466  1701  euthanized
# 467  1702       lived
# 468  1703        died
# 469  1704  euthanized
# 470  1705       lived
# 471  1706  euthanized
# 472  1707       lived
# 473  1708  euthanized
# 474  1709        died
# 475  1710  euthanized
# 476  1711       lived
# 477  1712       lived
# 478  1713       lived
# 479  1714  euthanized
# 480  1715        died
# 481  1716  euthanized
# 482  1717        died
# 483  1718  euthanized
# 484  1719       lived
# 485  1720        died
# 486  1721        died
# 487  1722       lived
# 488  1723        died
# 489  1724  euthanized
# 490  1725        died
# 491  1726        died
# 492  1727        died
# 493  1728       lived
# 494  1729  euthanized
# 495  1730        died
# 496  1731        died
# 497  1732  euthanized
# 498  1733        died
# 499  1734       lived
# 500  1735  euthanized
# 501  1736  euthanized
# 502  1737       lived
# 503  1738  euthanized
# 504  1739        died
# 505  1740  euthanized
# 506  1741       lived
# 507  1742       lived
# 508  1743        died
# 509  1744        died
# 510  1745  euthanized
# 511  1746        died
# 512  1747       lived
# 513  1748  euthanized
# 514  1749        died
# 515  1750        died
# 516  1751  euthanized
# 517  1752  euthanized
# 518  1753        died
# 519  1754        died
# 520  1755        died
# 521  1756  euthanized
# 522  1757  euthanized
# 523  1758        died
# 524  1759       lived
# 525  1760  euthanized
# 526  1761  euthanized
# 527  1762  euthanized
# 528  1763       lived
# 529  1764        died
# 530  1765       lived
# 531  1766  euthanized
# 532  1767  euthanized
# 533  1768  euthanized
# 534  1769        died
# 535  1770        died
# 536  1771       lived
# 537  1772        died
# 538  1773       lived
# 539  1774  euthanized
# 540  1775        died
# 541  1776        died
# 542  1777        died
# 543  1778        died
# 544  1779  euthanized
# 545  1780        died
# 546  1781  euthanized
# 547  1782  euthanized
# 548  1783  euthanized
# 549  1784       lived
# 550  1785  euthanized
# 551  1786       lived
# 552  1787       lived
# 553  1788  euthanized
# 554  1789  euthanized
# 555  1790  euthanized
# 556  1791        died
# 557  1792  euthanized
# 558  1793  euthanized
# 559  1794  euthanized
# 560  1795       lived
# 561  1796        died
# 562  1797       lived
# 563  1798        died
# 564  1799        died
# 565  1800        died
# 566  1801       lived
# 567  1802        died
# 568  1803        died
# 569  1804  euthanized
# 570  1805        died
# 571  1806       lived
# 572  1807  euthanized
# 573  1808        died
# 574  1809       lived
# 575  1810  euthanized
# 576  1811  euthanized
# 577  1812        died
# 578  1813       lived
# 579  1814       lived
# 580  1815        died
# 581  1816        died
# 582  1817       lived
# 583  1818       lived
# 584  1819  euthanized
# 585  1820        died
# 586  1821        died
# 587  1822       lived
# 588  1823       lived
# 589  1824  euthanized
# 590  1825  euthanized
# 591  1826       lived
# 592  1827       lived
# 593  1828        died
# 594  1829  euthanized
# 595  1830       lived
# 596  1831       lived
# 597  1832  euthanized
# 598  1833  euthanized
# 599  1834       lived
# 600  1835        died
# 601  1836  euthanized
# 602  1837  euthanized
# 603  1838  euthanized
# 604  1839        died
# 605  1840  euthanized
# 606  1841       lived
# 607  1842  euthanized
# 608  1843        died
# 609  1844        died
# 610  1845  euthanized
# 611  1846  euthanized
# 612  1847        died
# 613  1848       lived
# 614  1849       lived
# 615  1850        died
# 616  1851       lived
# 617  1852  euthanized
# 618  1853       lived
# 619  1854        died
# 620  1855        died
# 621  1856        died
# 622  1857       lived
# 623  1858  euthanized
# 624  1859  euthanized
# 625  1860       lived
# 626  1861       lived
# 627  1862        died
# 628  1863        died
# 629  1864       lived
# 630  1865        died
# 631  1866       lived
# 632  1867  euthanized
# 633  1868        died
# 634  1869        died
# 635  1870        died
# 636  1871       lived
# 637  1872       lived
# 638  1873        died
# 639  1874        died
# 640  1875  euthanized
# 641  1876       lived
# 642  1877  euthanized
# 643  1878       lived
# 644  1879        died
# 645  1880        died
# 646  1881        died
# 647  1882       lived
# 648  1883       lived
# 649  1884       lived
# 650  1885  euthanized
# 651  1886        died
# 652  1887       lived
# 653  1888        died
# 654  1889  euthanized
# 655  1890       lived
# 656  1891  euthanized
# 657  1892  euthanized
# 658  1893        died
# 659  1894       lived
# 660  1895        died
# 661  1896       lived
# 662  1897  euthanized
# 663  1898       lived
# 664  1899  euthanized
# 665  1900       lived
# 666  1901  euthanized
# 667  1902        died
# 668  1903       lived
# 669  1904  euthanized
# 670  1905  euthanized
# 671  1906  euthanized
# 672  1907  euthanized
# 673  1908  euthanized
# 674  1909  euthanized
# 675  1910        died
# 676  1911       lived
# 677  1912  euthanized
# 678  1913       lived
# 679  1914       lived
# 680  1915  euthanized
# 681  1916  euthanized
# 682  1917        died
# 683  1918       lived
# 684  1919       lived
# 685  1920       lived
# 686  1921       lived
# 687  1922        died
# 688  1923       lived
# 689  1924  euthanized
# 690  1925        died
# 691  1926       lived
# 692  1927        died
# 693  1928        died
# 694  1929  euthanized
# 695  1930        died
# 696  1931        died
# 697  1932       lived
# 698  1933        died
# 699  1934  euthanized
# 700  1935        died
# 701  1936  euthanized
# 702  1937  euthanized
# 703  1938        died
# 704  1939        died
# 705  1940       lived
# 706  1941  euthanized
# 707  1942       lived
# 708  1943       lived
# 709  1944       lived
# 710  1945  euthanized
# 711  1946  euthanized
# 712  1947        died
# 713  1948  euthanized
# 714  1949        died
# 715  1950  euthanized
# 716  1951  euthanized
# 717  1952  euthanized
# 718  1953        died
# 719  1954       lived
# 720  1955  euthanized
# 721  1956        died
# 722  1957        died
# 723  1958       lived
# 724  1959  euthanized
# 725  1960       lived
# 726  1961        died
# 727  1962       lived
# 728  1963  euthanized
# 729  1964        died
# 730  1965        died
# 731  1966       lived
# 732  1967       lived
# 733  1968  euthanized
# 734  1969       lived
# 735  1970       lived
# 736  1971       lived
# 737  1972  euthanized
# 738  1973  euthanized
# 739  1974  euthanized
# 740  1975  euthanized
# 741  1976  euthanized
# 742  1977  euthanized
# 743  1978       lived
# 744  1979        died
# 745  1980  euthanized
# 746  1981  euthanized
# 747  1982       lived
# 748  1983       lived
# 749  1984        died
# 750  1985  euthanized
# 751  1986       lived
# 752  1987        died
# 753  1988        died
# 754  1989  euthanized
# 755  1990       lived
# 756  1991       lived
# 757  1992       lived
# 758  1993  euthanized
# 759  1994        died
# 760  1995       lived
# 761  1996        died
# 762  1997  euthanized
# 763  1998  euthanized
# 764  1999  euthanized
# 765  2000  euthanized
# 766  2001  euthanized
# 767  2002  euthanized
# 768  2003       lived
# 769  2004  euthanized
# 770  2005        died
# 771  2006        died
# 772  2007  euthanized
# 773  2008        died
# 774  2009       lived
# 775  2010  euthanized
# 776  2011        died
# 777  2012        died
# 778  2013        died
# 779  2014  euthanized
# 780  2015       lived
# 781  2016       lived
# 782  2017  euthanized
# 783  2018  euthanized
# 784  2019  euthanized
# 785  2020       lived
# 786  2021  euthanized
# 787  2022        died
# 788  2023       lived
# 789  2024  euthanized
# 790  2025        died
# 791  2026       lived
# 792  2027  euthanized
# 793  2028  euthanized
# 794  2029       lived
# 795  2030  euthanized
# 796  2031       lived
# 797  2032  euthanized
# 798  2033        died
# 799  2034       lived
# 800  2035        died
# 801  2036       lived
# 802  2037       lived
# 803  2038        died
# 804  2039  euthanized
# 805  2040  euthanized
# 806  2041        died
# 807  2042       lived
# 808  2043       lived
# 809  2044  euthanized
# 810  2045  euthanized
# 811  2046       lived
# 812  2047       lived
# 813  2048  euthanized
# 814  2049  euthanized
# 815  2050  euthanized
# 816  2051  euthanized
# 817  2052        died
# 818  2053  euthanized
# 819  2054  euthanized
# 820  2055  euthanized
# 821  2056        died
# 822  2057       lived
# 823  2058       lived

# %% [markdown]
# ## Save the results to csv

# %%
sklearn_df.to_csv('sklearn_test_outcome.csv', index=False)
